# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn import metrics

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#       ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0      1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1      2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2      4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3      5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4      7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
# ..   ...      ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 328  500  0.17783   0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391
# 329  502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 330  503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 331  504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 332  506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# ...

# %%
df.isnull().sum()
# Out:
# ID         0
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       333 non-null    int64
#  1   crim     333 non-null    float64
#  2   zn       333 non-null    float64
#  3   indus    333 non-null    float64
#  4   chas     333 non-null    int64
#  5   nox      333 non-null    float64
#  6   rm       333 non-null    float64
#  7   age      333 non-null    float64
#  8   dis      333 non-null    float64
#  9   rad      333 non-null    int64
#  10  tax      333 non-null    int64
#  11  ptratio  333 non-null    float64
#  12  black    333 non-null    float64
#  13  lstat    333 non-null    float64
#  14  medv     333 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 39.2 KB

# %%
x=df[['ID','crim','zn','indus','chas','nox','rm','age','dis','rad','tax','ptratio','black','lstat']]

# %%
y=df[['medv']]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
model = LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = model.predict(x_test)
pred
# Out:
# array([[25.42935235],
#        [22.96355416],
#        [22.98361313],
#        [32.78417799],
#        [25.00393879],
#        [14.02939811],
#        [17.33416663],
#        [30.26235415],
#        [15.66094194],
#        [25.17645124],
#        [26.57561017],
#        [19.87047671],
#        [20.0909698 ],
#        [34.65458829],
#        [21.54826488],
#        [34.56267042],
#        [22.2485164 ],
#        [16.882139  ],
#        [25.36436429],
#        [16.87727359],
#        [36.17705665],
#        [31.39060697],
#        [22.8003689 ],
#        [28.13000873],
#        [17.20049765],
#        [42.37151734],
#        [ 7.87497041],
#        [-0.36689721],
#        [31.09480595],
#        [ 8.4983594 ],
#        [19.11933223],
#        [20.39461378],
#        [27.46125616],
#        [15.1123262 ],
#        [19.49023076],
#        [12.24379213],
#        [27.56523215],
#        [ 4.49445516],
#        [17.2050638 ],
#        [22.53286675],
#        [24.31038054],
# ...

# %%
model.score(x_test,y_test)
# Out:
# 0.7257587357992887

# %%
model.score(x_train,y_train)
# Out:
# 0.7322764285677805

# %%
print('MSE', metrics.mean_squared_error(y_test,pred))
# Out:
# MSE 23.26809178579522

# %%
sns.displot(x='age',data=df,height=4)

# %%
plt.scatter(y_test,pred)

# %%
df.plot.scatter('rm','medv')
# Out:
# <Axes: xlabel='rm', ylabel='medv'>

# %%
sns.displot((y_test),bins=50)

# %%
plt.figure(figsize=(6, 6))
plt.scatter(pred, y_test, color='blue', label='Actual vs. Predicted')
plt.plot([min(pred), max(pred)], [min(pred), max(pred)], '--', color='red', label='Perfect Fit')
plt.title('Linear Regression: Actual vs. Predicted Values')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.scatter(pred, y_test, color='blue', label='Actual vs. Predicted')
plt.plot([min(pred), max(pred)], [min(pred), max(pred)], '--', color='red', label='Perfect Fit')
plt.title('Linear Regression: Actual vs. Predicted Values')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.legend()
plt.show()
